# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from datetime import datetime, timedelta

# %% [markdown]
# # Strategy: Buy SPY on the 5th consecutive all-time high
# # hold for specified number of days

# %% [markdown]
# ## Specify parameters for analysis

# %%
holding_period = 5
start_date_string = "1993-02-01"
end_date_string = pd.Timestamp.today().strftime("%Y-%m-%d")

# %% [markdown]
# ## Get data

# %%
# Get daily price data
spy = yf.Ticker("SPY")
daily_ohlc = spy.history(start=start_date_string, end=end_date_string, interval="1D")
# Out:
# D:\Users\steve\anaconda3\envs\my_quant_lab2\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
daily_ohlc
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1993-02-01 00:00:00-05:00   24.858344   25.017353   24.858344   25.017353
# 1993-02-02 00:00:00-05:00   24.999690   25.088028   24.946687   25.070360
# 1993-02-03 00:00:00-05:00   25.105701   25.353048   25.088034   25.335381
# 1993-02-04 00:00:00-05:00   25.423697   25.494367   25.141015   25.441364
# 1993-02-05 00:00:00-05:00   25.423710   25.476713   25.282369   25.423710
# ...                               ...         ...         ...         ...
# 2024-01-18 00:00:00-05:00  474.010010  477.059998  472.420013  476.489990
# 2024-01-19 00:00:00-05:00  477.649994  482.720001  476.540009  482.429993
# 2024-01-22 00:00:00-05:00  484.010010  485.220001  482.779999  483.450012
# 2024-01-23 00:00:00-05:00  484.010010  485.109985  482.890015  484.859985
# 2024-01-24 00:00:00-05:00  487.809998  488.769989  484.880005  485.390015
#
#                               Volume  Dividends  Stock Splits  Capital Gains
# Date
# 1993-02-01 00:00:00-05:00     480500        0.0           0.0            0.0
# 1993-02-02 00:00:00-05:00     201300        0.0           0.0            0.0
# 1993-02-03 00:00:00-05:00     529400        0.0           0.0            0.0
# 1993-02-04 00:00:00-05:00     531500        0.0           0.0            0.0
# 1993-02-05 00:00:00-05:00     492100        0.0           0.0            0.0
# ...                              ...        ...           ...            ...
# 2024-01-18 00:00:00-05:00   91856200        0.0           0.0            0.0
# 2024-01-19 00:00:00-05:00  110733300        0.0           0.0            0.0
# 2024-01-22 00:00:00-05:00   75844900        0.0           0.0            0.0
# 2024-01-23 00:00:00-05:00   49945300        0.0           0.0            0.0
# 2024-01-24 00:00:00-05:00   81765000        0.0           0.0            0.0
#
# [7801 rows x 8 columns]

# %% [markdown]
# ## Calculate running all-time high to date, and identify trade setups

# %%
daily_ohlc['cummax'] = daily_ohlc['Close'].cummax()

# %%
# Identify which days had all-time highs
daily_ohlc.loc[daily_ohlc['Close'] == daily_ohlc['cummax'], 'cummax_int'] = 1
daily_ohlc.loc[daily_ohlc['Close'] != daily_ohlc['cummax'], 'cummax_int'] = 0

# %%
# A buy setup is the fifth consecutive all-time high
daily_ohlc.loc[daily_ohlc['cummax_int'].rolling(5).sum() == 5, 'buy_setup_int'] = 1
daily_ohlc.loc[daily_ohlc['cummax_int'].rolling(5).sum() < 5.0, 'buy_setup_int'] = 0

# %%
# Set target position to 1 (100%) for the holding period after a buy setup
daily_ohlc.loc[daily_ohlc['buy_setup_int'].rolling(holding_period).sum() >= 1, 'target_position'] = 1.00
daily_ohlc.loc[daily_ohlc['buy_setup_int'].rolling(holding_period).sum() < 1, 'target_position'] = 0.00

# %%
daily_ohlc.loc[daily_ohlc['target_position'] == 1]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1993-08-20 00:00:00-04:00   26.135987   26.207495   26.118110   26.207495
# 1993-08-23 00:00:00-04:00   26.100241   26.171748   26.100241   26.153872
# 1993-08-24 00:00:00-04:00   26.153871   26.439901   26.153871   26.439901
# 1993-08-25 00:00:00-04:00   26.439889   26.565027   26.404135   26.457766
# 1993-08-26 00:00:00-04:00   26.475653   26.618668   26.368391   26.475653
# ...                               ...         ...         ...         ...
# 2021-11-08 00:00:00-05:00  453.687984  454.199915  452.239118  452.944214
# 2021-11-09 00:00:00-05:00  453.320951  453.562428  449.998217  451.447083
# 2021-11-10 00:00:00-05:00  449.708392  451.447047  446.289091  447.815216
# 2021-11-11 00:00:00-05:00  449.351026  449.428316  447.940806  447.960114
# 2021-11-12 00:00:00-05:00  449.264089  451.910673  448.288510  451.340790
#
#                              Volume  Dividends  Stock Splits  Capital Gains  \
# Date
# 1993-08-20 00:00:00-04:00     80700        0.0           0.0            0.0
# 1993-08-23 00:00:00-04:00     15600        0.0           0.0            0.0
# 1993-08-24 00:00:00-04:00    273400        0.0           0.0            0.0
# 1993-08-25 00:00:00-04:00    242300        0.0           0.0            0.0
# 1993-08-26 00:00:00-04:00    120000        0.0           0.0            0.0
# ...                             ...        ...           ...            ...
# 2021-11-08 00:00:00-05:00  50405200        0.0           0.0            0.0
# 2021-11-09 00:00:00-05:00  51149100        0.0           0.0            0.0
# 2021-11-10 00:00:00-05:00  69429700        0.0           0.0            0.0
# 2021-11-11 00:00:00-05:00  34848500        0.0           0.0            0.0
# 2021-11-12 00:00:00-05:00  53466700        0.0           0.0            0.0
#
#                                cummax  cummax_int  buy_setup_int  \
# Date
# 1993-08-20 00:00:00-04:00   26.207495         1.0            1.0
# 1993-08-23 00:00:00-04:00   26.207495         0.0            0.0
# 1993-08-24 00:00:00-04:00   26.439901         1.0            0.0
# 1993-08-25 00:00:00-04:00   26.457766         1.0            0.0
# 1993-08-26 00:00:00-04:00   26.475653         1.0            0.0
# ...                               ...         ...            ...
# 2021-11-08 00:00:00-05:00  452.944214         1.0            1.0
# 2021-11-09 00:00:00-05:00  452.944214         0.0            0.0
# 2021-11-10 00:00:00-05:00  452.944214         0.0            0.0
# 2021-11-11 00:00:00-05:00  452.944214         0.0            0.0
# 2021-11-12 00:00:00-05:00  452.944214         0.0            0.0
#
#                            target_position
# Date
# 1993-08-20 00:00:00-04:00              1.0
# 1993-08-23 00:00:00-04:00              1.0
# 1993-08-24 00:00:00-04:00              1.0
# 1993-08-25 00:00:00-04:00              1.0
# 1993-08-26 00:00:00-04:00              1.0
# ...                                    ...
# 2021-11-08 00:00:00-05:00              1.0
# 2021-11-09 00:00:00-05:00              1.0
# 2021-11-10 00:00:00-05:00              1.0
# 2021-11-11 00:00:00-05:00              1.0
# 2021-11-12 00:00:00-05:00              1.0
#
# [163 rows x 12 columns]

# %% [markdown]
# ## Calculate net changes of entire time period (population) and of trades (sample)

# %%
# Select the days with buy or sell setups
transactions = daily_ohlc.loc[
    ((daily_ohlc['buy_setup_int'] == 1) & (daily_ohlc['buy_setup_int'].shift(1) == 0))
    | ((daily_ohlc['buy_setup_int'] == 0) & (daily_ohlc['buy_setup_int'].shift(1) == 1))][['Close', 'buy_setup_int']]

# %%
transactions['exit_close'] = transactions['Close'].shift(-1)
transactions['y_log_return'] = np.log(transactions['Close'].shift(-1)) - np.log(transactions['Close'])

# %%
transactions
# Out:
#                                 Close  buy_setup_int  exit_close  y_log_return
# Date
# 1993-08-20 00:00:00-04:00   26.207495            1.0   26.153872     -0.002048
# 1993-08-23 00:00:00-04:00   26.153872            0.0   28.738445      0.094239
# 1995-02-08 00:00:00-05:00   28.738445            1.0   28.942970      0.007092
# 1995-02-16 00:00:00-05:00   28.942970            0.0   31.726366      0.091821
# 1995-05-16 00:00:00-04:00   31.726366            1.0   31.604837     -0.003838
# 1995-05-17 00:00:00-04:00   31.604837            0.0   34.630070      0.091412
# 1995-09-08 00:00:00-04:00   34.630070            1.0   35.353710      0.020681
# 1995-09-15 00:00:00-04:00   35.353710            0.0   46.076611      0.264902
# 1996-11-19 00:00:00-05:00   46.076611            1.0   46.086266      0.000210
# 1996-11-21 00:00:00-05:00   46.086266            0.0   48.951431      0.060314
# 1997-01-22 00:00:00-05:00   48.951431            1.0   48.272343     -0.013970
# 1997-01-23 00:00:00-05:00   48.272343            0.0   55.449223      0.138609
# 1997-06-12 00:00:00-04:00   55.449223            1.0   55.858250      0.007350
# 1997-06-17 00:00:00-04:00   55.858250            0.0   69.471352      0.218097
# 1998-03-20 00:00:00-05:00   69.471352            1.0   69.313278     -0.002278
# 1998-03-23 00:00:00-05:00   69.313278            0.0  100.664398      0.373156
# 2006-11-20 00:00:00-05:00  100.664398            1.0  100.556923     -0.001068
# 2006-11-24 00:00:00-05:00  100.556923            0.0  104.618706      0.039598
# 2007-02-07 00:00:00-05:00  104.618706            1.0  104.481781     -0.001310
# 2007-02-08 00:00:00-05:00  104.481781            0.0  122.232651      0.156913
# 2013-01-24 00:00:00-05:00  122.232651            1.0  122.772575      0.004407
# 2013-01-28 00:00:00-05:00  122.772575            0.0  127.648483      0.038947
# 2013-03-11 00:00:00-04:00  127.648483            1.0  127.362160     -0.002246
# 2013-03-12 00:00:00-04:00  127.362160            0.0  134.223206      0.052469
# 2013-05-08 00:00:00-04:00  134.223206            1.0  133.845184     -0.002820
# 2013-05-09 00:00:00-04:00  133.845184            0.0  163.972687      0.203016
# 2014-06-10 00:00:00-04:00  163.972687            1.0  163.402634     -0.003483
# 2014-06-11 00:00:00-04:00  163.402634            0.0  172.789413      0.055856
# 2014-11-11 00:00:00-05:00  172.789413            1.0  172.603271     -0.001078
# 2014-11-12 00:00:00-05:00  172.603271            0.0  177.606339      0.028574
# 2014-12-29 00:00:00-05:00  177.606339            1.0  176.653351     -0.005380
# 2014-12-30 00:00:00-05:00  176.653351            0.0  208.407043      0.165304
# 2017-02-15 00:00:00-05:00  208.407043            1.0  208.229614     -0.000852
# 2017-02-16 00:00:00-05:00  208.229614            0.0  227.790451      0.089785
# 2017-10-04 00:00:00-04:00  227.790451            1.0  228.879166      0.004768
# 2017-10-06 00:00:00-04:00  228.879166            0.0  231.344589      0.010714
# 2017-10-20 00:00:00-04:00  231.344589            1.0  230.444778     -0.003897
# 2017-10-23 00:00:00-04:00  230.444778            0.0  247.729858      0.072328
# 2018-01-08 00:00:00-05:00  247.729858            1.0  247.910721      0.000730
# 2018-01-10 00:00:00-05:00  247.910721            0.0  291.558624      0.162172
# 2019-11-18 00:00:00-05:00  291.558624            1.0  291.474518     -0.000289
# 2019-11-19 00:00:00-05:00  291.474518            0.0  298.632202      0.024260
# 2019-12-18 00:00:00-05:00  298.632202            1.0  303.170929      0.015084
# 2019-12-27 00:00:00-05:00  303.170929            0.0  330.458984      0.086186
# 2020-08-27 00:00:00-04:00  330.458984            1.0  331.388733      0.002810
# 2020-08-31 00:00:00-04:00  331.388733            0.0  396.215881      0.178667
# 2021-04-13 00:00:00-04:00  396.215881            1.0  394.862732     -0.003421
# 2021-04-14 00:00:00-04:00  394.862732            0.0  412.147095      0.042842
# 2021-06-30 00:00:00-04:00  412.147095            1.0  416.836029      0.011313
# 2021-07-06 00:00:00-04:00  416.836029            0.0  430.354065      0.031915
# 2021-08-16 00:00:00-04:00  430.354065            1.0  427.533051     -0.006577
# 2021-08-17 00:00:00-04:00  427.533051            0.0  448.877716      0.048719
# 2021-11-03 00:00:00-04:00  448.877716            1.0  451.447083      0.005708
# 2021-11-09 00:00:00-05:00  451.447083            0.0         NaN           NaN

# %%
trades = transactions.loc[transactions['buy_setup_int'] == 1]

# %%
trades
# Out:
#                                 Close  buy_setup_int  exit_close  y_log_return
# Date
# 1993-08-20 00:00:00-04:00   26.207495            1.0   26.153872     -0.002048
# 1995-02-08 00:00:00-05:00   28.738445            1.0   28.942970      0.007092
# 1995-05-16 00:00:00-04:00   31.726366            1.0   31.604837     -0.003838
# 1995-09-08 00:00:00-04:00   34.630070            1.0   35.353710      0.020681
# 1996-11-19 00:00:00-05:00   46.076611            1.0   46.086266      0.000210
# 1997-01-22 00:00:00-05:00   48.951431            1.0   48.272343     -0.013970
# 1997-06-12 00:00:00-04:00   55.449223            1.0   55.858250      0.007350
# 1998-03-20 00:00:00-05:00   69.471352            1.0   69.313278     -0.002278
# 2006-11-20 00:00:00-05:00  100.664398            1.0  100.556923     -0.001068
# 2007-02-07 00:00:00-05:00  104.618706            1.0  104.481781     -0.001310
# 2013-01-24 00:00:00-05:00  122.232651            1.0  122.772575      0.004407
# 2013-03-11 00:00:00-04:00  127.648483            1.0  127.362160     -0.002246
# 2013-05-08 00:00:00-04:00  134.223206            1.0  133.845184     -0.002820
# 2014-06-10 00:00:00-04:00  163.972687            1.0  163.402634     -0.003483
# 2014-11-11 00:00:00-05:00  172.789413            1.0  172.603271     -0.001078
# 2014-12-29 00:00:00-05:00  177.606339            1.0  176.653351     -0.005380
# 2017-02-15 00:00:00-05:00  208.407043            1.0  208.229614     -0.000852
# 2017-10-04 00:00:00-04:00  227.790451            1.0  228.879166      0.004768
# 2017-10-20 00:00:00-04:00  231.344589            1.0  230.444778     -0.003897
# 2018-01-08 00:00:00-05:00  247.729858            1.0  247.910721      0.000730
# 2019-11-18 00:00:00-05:00  291.558624            1.0  291.474518     -0.000289
# 2019-12-18 00:00:00-05:00  298.632202            1.0  303.170929      0.015084
# 2020-08-27 00:00:00-04:00  330.458984            1.0  331.388733      0.002810
# 2021-04-13 00:00:00-04:00  396.215881            1.0  394.862732     -0.003421
# 2021-06-30 00:00:00-04:00  412.147095            1.0  416.836029      0.011313
# 2021-08-16 00:00:00-04:00  430.354065            1.0  427.533051     -0.006577
# 2021-11-03 00:00:00-04:00  448.877716            1.0  451.447083      0.005708

# %%
# Get log returns for the entire population based on the holding period
population = daily_ohlc.iloc[::holding_period][['Close', 'buy_setup_int']]

# %%
# Repeat the same calculations for the population
population['exit_close'] = population['Close'].shift(-1)
population['y_log_return'] = np.log(population['Close'].shift(-1)) - np.log(population['Close'])

# %%
population
# Out:
#                                 Close  buy_setup_int  exit_close  y_log_return
# Date
# 1993-02-01 00:00:00-05:00   25.017353            NaN   25.423710      0.016112
# 1993-02-08 00:00:00-05:00   25.423710            0.0   24.575674     -0.033925
# 1993-02-16 00:00:00-05:00   24.575674            0.0   24.699341      0.005019
# 1993-02-23 00:00:00-05:00   24.699341            0.0   25.406034      0.028210
# 1993-03-02 00:00:00-05:00   25.406034            0.0   25.777058      0.014498
# ...                               ...            ...         ...           ...
# 2023-12-22 00:00:00-05:00  473.649994            0.0  472.649994     -0.002113
# 2024-01-02 00:00:00-05:00  472.649994            0.0  473.880005      0.002599
# 2024-01-09 00:00:00-05:00  473.880005            0.0  472.290009     -0.003361
# 2024-01-17 00:00:00-05:00  472.290009            0.0  485.390015      0.027359
# 2024-01-24 00:00:00-05:00  485.390015            0.0         NaN           NaN
#
# [1561 rows x 4 columns]

# %% [markdown]
# ## Calculate backtest statistics

# %%
trades['y_log_return'].describe()
# Out:
# count    27.000000
# mean      0.000948
# std       0.007057
# min      -0.013970
# 25%      -0.003121
# 50%      -0.001068
# 75%       0.004588
# max       0.020681
# Name: y_log_return, dtype: float64

# %%
print("The sample mean log return is ", trades['y_log_return'].mean())
print("The population mean log return is ", population['y_log_return'].mean())
# Out:
# The sample mean log return is  0.0009480565009756083
# The population mean log return is  0.001900886548270566

# %%
print("Backtest sample statistics (log returns):")
print("Mean: ", trades['y_log_return'].mean())
print("Standard deviation: ", trades['y_log_return'].std())
print("N: ", trades['y_log_return'].count())
print("t: ", (trades['y_log_return'].mean() - population['y_log_return'].mean()) / (trades['y_log_return'].std() / (trades['y_log_return'].count() ** 0.5)))
# Out:
# Backtest sample statistics (log returns):
# Mean:  0.0009480565009756083
# Standard deviation:  0.007056811349865626
# N:  27
# t:  -0.7015987693611289

# %%
trades.iloc[-10:]
# Out:
#                                 Close  buy_setup_int  exit_close  y_log_return
# Date
# 2017-10-04 00:00:00-04:00  227.790451            1.0  228.879166      0.004768
# 2017-10-20 00:00:00-04:00  231.344589            1.0  230.444778     -0.003897
# 2018-01-08 00:00:00-05:00  247.729858            1.0  247.910721      0.000730
# 2019-11-18 00:00:00-05:00  291.558624            1.0  291.474518     -0.000289
# 2019-12-18 00:00:00-05:00  298.632202            1.0  303.170929      0.015084
# 2020-08-27 00:00:00-04:00  330.458984            1.0  331.388733      0.002810
# 2021-04-13 00:00:00-04:00  396.215881            1.0  394.862732     -0.003421
# 2021-06-30 00:00:00-04:00  412.147095            1.0  416.836029      0.011313
# 2021-08-16 00:00:00-04:00  430.354065            1.0  427.533051     -0.006577
# 2021-11-03 00:00:00-04:00  448.877716            1.0  451.447083      0.005708
